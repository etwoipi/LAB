# %% [markdown]
# ###

# %% [markdown]
# target_imgs # 10
#
# target_img_A <= (0,0)
# target_img_B <= (1,1)
#
# field_A = torch.exp(1jphase_A)
# field_B = torch.exp(1jphase_B)
#
# inter_phase = phase_A * x + phase_B * (1-x)
#
# field_inter = torch.exp(1j*inter_phase)
#
# tt.simulate(field_inter, 20e-3)

# %% [markdown]
# ### Code

# %%
# import

import torch.nn as nn
import torch
import sys, os
sys.path.append(os.pardir)
from torchOptics import optics as tt
from torchOptics import models as tm
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
from tqdm import tqdm

# %%
meta = {'wl':(638e-9, 515e-9, 450e-9), 'dx': (6.3e-6, 6.3e-6)}

# %%
# array1

size = 512  #배열 크기
sigma = 10  #표준편차
phase1 = np.zeros((size, size), dtype=np.float64)
amplitude = 1

#gaussian 추가
def add_gaussian(x1, y1, sigma, amplitude=amplitude):
    y, x = np.indices((size, size))
    x1 = float(x1)
    y1 = float(y1)
    gaussian = amplitude * np.exp(-((x-x1)**2+(y-y1)**2)/(2*sigma**2))
    return gaussian

centers = [(200, 200), (200, 350), (350, 350), (350, 200)]
for center in centers:
    phase1 += add_gaussian(center[0], center[1], sigma)

phase1 = tt.Tensor(phase1, meta=meta)

# %%
# array2
p=10
phase2 = np.zeros((size, size), dtype=np.float64)
centers = [(200+p, 200), (200+p, 350), (350+p, 350), (350+p, 200)]
for center in centers:
    phase2 += add_gaussian(center[0], center[1], sigma)

phase2 = tt.Tensor(phase2, meta=meta)

# %%
SLM_phase1 = phase1
timg = SLM_phase1
phase = torch.ones_like(timg)
phase.requires_grad = True
optimizer = torch.optim.Adam([phase], lr=0.001)
criterion = torch.nn.MSELoss()
pbar = tqdm(range(10000))
for i in pbar :
    optimizer.zero_grad()
    field1 = torch.exp(1j*phase)
    sim = tt.simulate(field1, 20e-3).abs()**2
    loss = criterion(sim, timg)
    loss.backward()
    optimizer.step()
    pbar.set_description('{:.4f}'.format(loss.item()))
# Out:
# 0.0002: 100%|██████████| 10000/10000 [01:28<00:00, 112.49it/s]

# %%
tt.simulate(field1, 20e-3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# {'wl': (6.38e-07, 5.15e-07, 4.5e-07), 'dx': (6.3e-06, 6.3e-06)}

# %%
SLM_phase2 = phase2
timg = SLM_phase2
phase_ = torch.ones_like(timg)
phase_.requires_grad = True
optimizer = torch.optim.Adam([phase_], lr=0.001)
criterion = torch.nn.MSELoss()
pbar = tqdm(range(10000))
for i in pbar :
    optimizer.zero_grad()
    field2 = torch.exp(1j*phase_)
    sim = tt.simulate(field2, 20e-3).abs()**2
    loss = criterion(sim, timg)
    loss.backward()
    optimizer.step()
    pbar.set_description('{:.4f}'.format(loss.item()))
# Out:
# 0.0002: 100%|██████████| 10000/10000 [01:29<00:00, 111.21it/s]

# %%
tt.simulate(field2, 20e-3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# {'wl': (6.38e-07, 5.15e-07, 4.5e-07), 'dx': (6.3e-06, 6.3e-06)}

# %%
x = 0.5
SLM_phase_inter = tt.Tensor(torch.exp(1j*(phase_*x + phase*(1-x))), meta=meta)
timg = SLM_phase_inter
phase_inter = tt.Tensor(torch.ones_like(timg, dtype=torch.complex128), meta=meta)
phase_inter.requires_grad = True
optimizer = torch.optim.Adam([phase_inter], lr=0.001)
criterion = torch.nn.MSELoss()
pbar = tqdm(range(10000))
for i in pbar :
    optimizer.zero_grad()
    field3 = torch.exp(1j*phase_inter)
    sim = tt.simulate(field3, 20e-3).abs()**2
    loss = criterion(sim, timg)
    loss.backward(retain_graph=True)
    optimizer.step()
    pbar.set_description('{:.4f}'.format(loss.item()))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:85, in _complex_not_implemented.<locals>.wrapper(*args, **kwargs)
#      84 try:
# ---> 85     return func(*args, **kwargs)
#      86 except RuntimeError as e:
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:170, in Tensor.__torch_function__(self, func, types, args, kwargs)
#     168 @_complex_not_implemented
#     169 def __torch_function__(self, func, types, args=(), kwargs=None):
# --> 170     r = super().__torch_function__(func=func, types=types, args=args, kwargs=kwargs)
#     171     if isinstance(r, Tensor) and hasattr(self, 'meta') and self.meta:
#
# File /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:1273, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1272 with _C.DisableTorchFunction():
# -> 1273     ret = func(*args, **kwargs)
#    1274     if func in get_default_nowrap_functions():
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:3288, in mse_loss(input, target, size_average, reduce, reduction)
#    3287 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3288 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# RuntimeError: "mse_cuda" not implemented for 'ComplexDouble'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 13
#      11 field3 = torch.exp(1j*phase_inter)
#      12 sim = tt.simulate(field3, 20e-3).abs()**2
# ---> 13 loss = criterion(sim, timg)
#      14 loss.backward(retain_graph=True)
#      15 optimizer.step()
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/loss.py:536, in MSELoss.forward(self, input, target)
#     535 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 536     return F.mse_loss(input, target, reduction=self.reduction)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:3274, in mse_loss(input, target, size_average, reduce, reduction)
#    3267 r"""mse_loss(input, target, size_average=None, reduce=None, reduction='mean') -> Tensor
#    3268
#    3269 Measures the element-wise mean squared error.
#    3270
#    3271 See :class:`~torch.nn.MSELoss` for details.
#    3272 """
#    3273 if has_torch_function_variadic(input, target):
# -> 3274     return handle_torch_function(
#    3275         mse_loss, (input, target), input, target, size_average=size_average, reduce=reduce, reduction=reduction
#    3276     )
#    3277 if not (target.size() == input.size()):
#    3278     warnings.warn(
#    3279         "Using a target size ({}) that is different to the input size ({}). "
#    3280         "This will likely lead to incorrect results due to broadcasting. "
#    3281         "Please ensure they have the same size.".format(target.size(), input.size()),
#    3282         stacklevel=2,
#    3283     )
#
# File /usr/local/lib/python3.8/dist-packages/torch/overrides.py:1534, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1528     warnings.warn("Defining your `__torch_function__ as a plain method is deprecated and "
#    1529                   "will be an error in future, please define it as a classmethod.",
#    1530                   DeprecationWarning)
#    1532 # Use `public_api` instead of `implementation` so __torch_function__
#    1533 # implementations can do equality/identity comparisons.
# -> 1534 result = torch_func_method(public_api, types, args, kwargs)
#    1536 if result is not NotImplemented:
#    1537     return result
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:96, in _complex_not_implemented.<locals>.wrapper(*args, **kwargs)
#      93     else:
#      94         return [_to_float(a) for a in arg]
# ---> 96 n_args = [_to_float_iterable(arg) if (isinstance(arg, Iterable) and (not isinstance(arg, torch.Tensor))) else _to_float(arg) for arg in args]
#      97 r = func(*n_args, **kwargs)
#      98 return complexToEnd(r)
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:96, in <listcomp>(.0)
#      93     else:
#      94         return [_to_float(a) for a in arg]
# ---> 96 n_args = [_to_float_iterable(arg) if (isinstance(arg, Iterable) and (not isinstance(arg, torch.Tensor))) else _to_float(arg) for arg in args]
#      97 r = func(*n_args, **kwargs)
#      98 return complexToEnd(r)
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:94, in _complex_not_implemented.<locals>.wrapper.<locals>._to_float_iterable(arg)
#      92     return {k:v for k,v in arg.items()}
#      93 else:
# ---> 94     return [_to_float(a) for a in arg]
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:94, in <listcomp>(.0)
#      92     return {k:v for k,v in arg.items()}
#      93 else:
# ---> 94     return [_to_float(a) for a in arg]
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:89, in _complex_not_implemented.<locals>.wrapper.<locals>._to_float(tensor)
#      88 def _to_float(tensor):
# ---> 89     return complexToChannel(tensor) if isComplex(tensor) else tensor
#
# File /home/hana1029/OpticalTweezer/../torchOptics/optics.py:924, in complexToChannel(tensor)
#     922 if isComplex(tensor):
#     923     shape = tensor.shape
# --> 924     return view_as_float(tensor).unsqueeze(-4).transpose(-1,-4).squeeze(-1).reshape(*shape[:-3], shape[-3]*2, *shape[-2:])
#     925 else:
#     926     return tensor
#
# IndexError: tuple index out of range

# %%
tt.simulate(torch.exp(1j*(phase_*x+phase*(1-x))), 20e-3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# {'wl': 5.15e-07, 'dx': (6.3e-06, 6.3e-06)}

# %%
tt.simulate(field2-field3, 20e-3)
# Out:
# {'wl': (6.38e-07, 5.15e-07, 4.5e-07), 'dx': (6.3e-06, 6.3e-06)}

# %%
tt.simulate(field1-field3, 20e-3)
# Out:
# {'wl': (6.38e-07, 5.15e-07, 4.5e-07), 'dx': (6.3e-06, 6.3e-06)}
